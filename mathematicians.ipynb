# %% [markdown]
# Time to say this to matlab

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("Z5RNiWpQDX4",width = 500,heigh = 500)

# %% [markdown]
# #The libraries
#
# ##sympy
# ##scipy

# %% [markdown]
# #**YOU CAN FOCUS ON YOUR CALCULUS**

# %% [markdown]
# Solving the Equation

# %%
import sympy as sp
x,y,z = sp.symbols("x y z")

# %%
print(x*y)
# Out:
# x*y

# %% [markdown]
# #make it look as the maths

# %%
sp.pprint(x*y)
# Out:
# x⋅y

# %%
sp.pretty_print(x*y)
# Out:
# x⋅y

# %%
f = x**3 - 2*x + 1

# %%
print(f)
# Out:
# x**3 - 2*x + 1

# %%
sp.pprint(f)
# Out:
#  3
# x  - 2⋅x + 1

# %%
print(f.subs(x,2))
# Out:
# 5

# %%
sp.pprint(f.subs(x,2))
# Out:
# 5

# %%
sp.pprint(f.factor())
# Out:
#         ⎛ 2        ⎞
# (x - 1)⋅⎝x  + x - 1⎠

# %% [markdown]
# #plot it

# %%
sp.plot(f)

# %%
equation = sp.Eq(f,0)

# %%
print("te solution" + str(sp.solve(equation)))
# Out:
# te solution[1, -1/2 + sqrt(5)/2, -sqrt(5)/2 - 1/2]

# %%
print((10-1)/(2-1))
# Out:
# 9.0

# %%
print((0-12)/9)
# Out:
# -1.3333333333333333

# %%
a,b,c = sp.symbols("a b c")

# %% [markdown]
# #The Equation Function

# %%
eq1 = sp.Eq(a+b+c,2)

# %%
eq2 = sp.Eq(4*a +2**b,4)

# %%
eq3 = sp.Eq(9*a +3*b+c,7)

# %%
sp.pprint(sp.solve([eq1,eq2,eq3]))
# Out:
# ⎡⎧                                      ⎛        ⎛    ⎛ √2⎞⎞         ⎞
# ⎢⎪           ⎛    ⎛ √2⎞⎞                ⎜        ⎜    ⎜ ──⎟⎟         ⎟
# ⎢⎪           ⎜    ⎜ ──⎟⎟                ⎜        ⎜    ⎜ 4 ⎟⎟   log(8)⎟
# ⎢⎨           ⎜    ⎜ 4 ⎟⎟               -⎜LambertW⎝-log⎝2  ⎠⎠ + ──────⎟
# ⎢⎪   LambertW⎝-log⎝2  ⎠⎠ + log(16)      ⎝                        2   ⎠      3⋅
# ⎢⎪a: ─────────────────────────────, b: ────────────────────────────────, c: ──
# ⎣⎩              4⋅log(2)                            log(2)
#
#                                ⎫  ⎧                                          ⎛
#         ⎛    ⎛ √2⎞⎞            ⎪  ⎪           ⎛    ⎛ √2⎞    ⎞                ⎜
#         ⎜    ⎜ ──⎟⎟            ⎪  ⎪           ⎜    ⎜ ──⎟    ⎟                ⎜
#         ⎜    ⎜ 4 ⎟⎟            ⎬  ⎨           ⎜    ⎜ 4 ⎟    ⎟               -⎜
# LambertW⎝-log⎝2  ⎠⎠ + log(1024)⎪  ⎪   LambertW⎝-log⎝2  ⎠, -1⎠ + log(16)      ⎝
# ...

# %%
sp.pprint(eq1)
# Out:
# a + b + c = 2

# %%
sp.pprint(eq2)
# Out:
#  b
# 2  + 4⋅a = 4

# %%
sp.pprint(eq3)
# Out:
# 9⋅a + 3⋅b + c = 7

# %%
import sympy as sp
a,b,c,d,n = sp.symbols(" a b c d n ")

# %%
an = 9 - 4*(n-1)
print(an)
# Out:
# -4*n + 13

# %%
sp.pprint(an)
# Out:
# -4⋅n + 13

# %%
an.subs(n,2)
# Out:
# 5

# %%
print(an.subs(n,4))
# Out:
# -3

# %%
eq1 = sp.Eq(a+b+c,9)

# %%
eq2 = sp.Eq(4*a  + a + 2*b+c,5)

# %%
eq3 = sp.Eq(n+a+b**2-(34*a)/b,7)

# %%
sp.pprint(sp.solve(eq1))
# Out:
# [{a: -b - c + 9}]

# %%
sp.pprint(sp.solve([eq1,eq2,eq3]))
# Out:
# ⎡⎧
# ⎢⎪         _______________________________________________________________
# ⎢⎪        ╱                  ____________________________________
# ⎢⎪     3 ╱                  ╱      3        2                                3
# ⎢⎪   n⋅╲╱   -72⋅n + 12⋅√3⋅╲╱  256⋅n  + 380⋅n  + 9980⋅n + 2002359  - 29411  + ─
# ⎢⎨
# ⎢⎪a: ─────────────────────────────────────────────────────────────────────────
# ⎢⎪
# ⎢⎪
# ⎢⎪
# ⎣⎩
#
#                                                                        2/3
#         ⎛                 ____________________________________        ⎞
#         ⎜                ╱      3        2                            ⎟
# ⋅n   49⋅⎝-72⋅n + 12⋅√3⋅╲╱  256⋅n  + 380⋅n  + 9980⋅n + 2002359  - 29411⎠      2
# ── - ───────────────────────────────────────────────────────────────────── + ─
# 2                                      48
# ──────────────────────────────────────────────────────────────────────────────
#
# ...

# %%
an = (9-4*(n-1))

# %%
print(an.subs(n,2))
# Out:
# 5

# %%
eq1 = sp.Eq(a+b+c,10)

# %%
eq2 = sp.Eq(8*a+4*b+2*c+d,5)

# %%
eq3 = sp.Eq(27*a+9*b+3*c+d,4)

# %%
eq4 = sp.Eq(64+a*a+4*c,6)

# %%
sp.solve([eq1,eq2,eq3,eq4])
# Out:
# [{a: -7 - 2*sqrt(15)*I,
#   b: 115/4 + 9*sqrt(15)*I,
#   c: -47/4 - 7*sqrt(15)*I,
#   d: -61/2 - 6*sqrt(15)*I},
#  {a: -7 + 2*sqrt(15)*I,
#   b: 115/4 - 9*sqrt(15)*I,
#   c: -47/4 + 7*sqrt(15)*I,
#   d: -61/2 + 6*sqrt(15)*I}]

# %%
a = sp.sqrt(100)

# %%
sp.pprint(sp.sqrt(1000))
# Out:
# 10⋅√10

# %%
import sympy as sp
x = sp.Symbol("x")
sp.diff(3*x**2 +1,x)
# Out:
# 6*x

# %%
import sympy as sp
t = sp.symbols('t')
x = t*sp.cos(t)**3  - (t-2)**2 /20

# %%
sp.pprint(x)
# Out:
#                    2
#      3      (t - 2)
# t⋅cos (t) - ────────
#                20

# %%
x = t*sp.cos(t)**3  - (t-2)**2/20

# %%
sp.plot(x,xlim = (0,6),ylim = (-5,1),show = True)

# %%
graph = (t,x,(t,0.5))

# %%
circ = (.05*sp.cos(t)+3,.05*sp.sin(t) + x.subs(t,3),(t,0,6.5))

# %%
t2 = 4
line = (t,(x.subs(t,t2) -x.subs(t,3))/ (t2-3)*(t-3) + x.subs(t,3),(t,1,5) )

# %%
p = sp.plotting.plot_parametric(graph,circ,line)
p[1].line_color = "r"
p[2].line_color = "g"
p.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-222-999e5ec47eb9> in <module>()
# ----> 1 p = sp.plotting.plot_parametric(graph,circ,line)
#       2 p[1].line_color = "r"
#       3 p[2].line_color = "g"
#       4 p.show()
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py in plot_parametric(*args, **kwargs)
#    1420     show = kwargs.pop('show', True)
#    1421     series = []
# -> 1422     plot_expr = check_arguments(args, 2, 1)
#    1423     series = [Parametric2DLineSeries(*arg, **kwargs) for arg in plot_expr]
#    1424     plots = Plot(*series, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py in check_arguments(args, expr_len, nb_of_free_symbols)
#    1826                 if not len(arg[i + expr_len]) == 3:
#    1827                     raise ValueError("The ranges should be a tuple of "
# ...

# %%
import sympy as sp

# %%
t = sp.symbols("t")

# %%
x = 2*t**3 - t+3

# %%
print(x.subs(t,1))
# Out:
# 4

# %%
print(x.subs(t,2))
# Out:
# 17

# %%
print((x.subs(t,1.5) - x.subs(t,1))/(1.5-1))
# Out:
# 8.50000000000000

# %%
print((x.subs(t,1.000000000000000000000000005) - x.subs(t,1))/(1.500005-1))
# Out:
# 0

# %%
f = t*sp.sin(t)

# %%
print(((f.subs(t,sp.pi+0.0000001) - f.subs(t,sp.pi))/(sp.pi+0.000000001)).evalf())
# Out:
# -1.00000003151268e-7

# %%
import sympy as sp
s = sp.symbols("x")

# %%
fleft = -x+1
fright = x-2

# %%
xlist = []

# %%
side = 1

# %%
for i in range(10):
  aa = side*2**(-i)
  print(aa)
  xlist.append(a)
# Out:
# 1
# 0.5
# 0.25
# 0.125
# 0.0625
# 0.03125
# 0.015625
# 0.0078125
# 0.00390625
# 0.001953125

# %%
sidelist = [fleft,fright]

# %%
sideind = int(side/2+.5)

# %%
ylist = []

# %%
funclist = []

# %%
print("the sequence of values")
for i in range(10):
  a = side*2**(-i)
  print(sidelist[sideind].subs(x,a))
  ylist.append(sidelist[sideind].subs(x,a))
  funclist.append(func)
# Out:
# the sequence of values
# -1
# -1.50000000000000
# -1.75000000000000
# -1.87500000000000
# -1.93750000000000
# -1.96875000000000
# -1.98437500000000
# -1.99218750000000
# -1.99609375000000
# -1.99804687500000

# %%
sp.plot(*funclist, (x,sidelist[sideind],(x,0.3)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-270-d5bb518a3aab> in <module>()
# ----> 1 sp.plot(*funclist, (x,sidelist[sideind],(x,0.3)))
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py in plot(*args, **kwargs)
#    1289     series = []
#    1290     plot_expr = check_arguments(args, 1, 1)
# -> 1291     series = [LineOver1DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    1292
#    1293     plots = Plot(*series, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py in <listcomp>(.0)
#    1289     series = []
#    1290     plot_expr = check_arguments(args, 1, 1)
# -> 1291     series = [LineOver1DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    1292
#    1293     plots = Plot(*series, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/plot.py in __init__(self, expr, var_start_end, **kwargs)
# ...

# %%
import sympy as sp
x = sp.symbols('x')

# f(x) = (sqrt(x)-1) / (x-1)
f = (sp.sqrt(x)-1) / (x-1)
conjugate = sp.sqrt(x)+1
sp.pprint(f)
# Use the conjugate, but sympy cancels it before using it.
print()
sp.pprint( (f * conjugate) / conjugate )
# Force sympy to usse the conjugate before canceling
print()
sp.pprint( (f * conjugate).simplify() / conjugate )
# Out:
# √x - 1
# ──────
# x - 1
#
# √x - 1
# ──────
# x - 1
#
#   1
# ──────
# √x + 1

# %%
import sympy as sp
from sympy import stats
from sympy.plotting.plot import Parametric2DLineSeries as parPlot
from sympy.plotting import plot as plt
r, s, e, d = sp.symbols('r s e d')

e = .5
print("e = " + str(e))
d = e/2.5
print("d = " + str(d))
x0 = 1
U = stats.Uniform('U2', x0-d, x0+d)
x = stats.sample(U)
fx = x**2
print("x = " + str(x) + " and fx = " + str(fx))

sp.plotting.plot_parametric( (x0, r, (r,0,4)), (r, x0**2, (r,0,4)),
                             (x0+d, r, (r,0,4)), (x0-d, r, (r,0,4)),
                             (r, x0**2-e, (r,0,4)), (r, x0**2+e, (r,0,4)),
    (r, r**2, (r, 0, 2)),  (.05*sp.cos(r)+x, .06*sp.sin(r)+fx, (r,0,6.5)) )
# Out:
# e = 0.5
# d = 0.2
# x = 0.975308674280285 and fx = 0.951227010126367

# %%
import sympy as sp

# %%
x = sp.symbols("x")

# %%
f = x**2 + sp.E**x

# %%
sp.pprint(f)
# Out:
#  2    x
# x  + ℯ

# %%
g = sp.tan(x)

# %%
f = f/g

# %%
sp.pprint(sp.limit(h,x,0))
# Out:
# 0

# %%
sp.pprint(sp.limit(h,x,sp.pi))
# Out:
#  2
# π

# %%
sp.pprint(sp.limit(h,x,sp.pi/2))
# Out:
#  2
# π
# ──
# 4

# %%
i = sp.sqrt(x)

# %%
print(i)
# Out:
# sqrt(x)

# %%
sp.pprint(sp.limit(i,x,0))
# Out:
# 0

# %%
import sympy as sp
import sympy as sp
from sympy import stats
from sympy.plotting.plot import Parametric2DLineSeries as parPlot
from sympy.plotting import plot as plt
s = sp.symbol("x")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-271-3e892c1dd11d> in <module>()
#       1 import sympy as sp
# ----> 2 s = sp.symbol("x")
#
# TypeError: 'module' object is not callable

# %%
flseft = -x+2
fright = x+2

# %%
sp.plot( (fleft,(x,-2,0)),(fright,(x,0,2)))
# Out:
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/experimental_lambdify.py:232: UserWarning: The evaluation of the expression is problematic. We are trying a failback method that may still work. Please report this as a bug.
#   warnings.warn('The evaluation of the expression is'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sympy/plotting/experimental_lambdify.py in __call__(self, args)
#     193             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 194             result = complex(self.lambda_func(args))
#     195             if abs(result.imag) > 1e-7 * abs(result):
#
# /usr/local/lib/python3.6/dist-packages/sympy/core/expr.py in __complex__(self)
#     243         re, im = result.as_real_imag()
# --> 244         return complex(float(re), float(im))
#     245
#
# ...

# %%
import sympy as sym
from sympy.abc import s,t,x,y,z
from sympy.integrals import laplace_transform
from sympy.integrals import inverse_laplace_transform

# Laplace transform (t->s)
U = laplace_transform(5*t, t, s)
print('U')
print(U[0])
# Result: 5/s**2

# Inverse Laplace transform (s->t)
X = inverse_laplace_transform(U[0],s,t)
print('X')
print(X)
# Result: 5*t*Heaviside(t)

# Function
F = 5*(s+1)/(s+3)**2
print('F')
print(F)
# Result: (5*s + 5)/(s + 3)**2

# Partial fraction decomposition
G = sym.apart(F)
print('G')
print(G)
# Result: 5/(s + 3) - 10/(s + 3)**2

# denominator of transfer function
d1 = (s+1)*(s+3)*(s**2+3*s+1)

# expand polynomial
d2 = sym.expand(d1)
print('d2')
print(d2)
# Result: s**4 + 7*s**3 + 16*s**2 + 13*s + 3

# find roots
print(sym.roots(d2))
# Result: {-1: 1, -3: 1, -3/2 - sqrt(5)/2: 1, -3/2 + sqrt(5)/2: 1}
# Out:
# U
# 5/s**2
# X
# 5*t*Heaviside(t)
# F
# (5*s + 5)/(s + 3)**2
# G
# 5/(s + 3) - 10/(s + 3)**2
# d2
# s**4 + 7*s**3 + 16*s**2 + 13*s + 3
# {-1: 1, -3: 1, -3/2 - sqrt(5)/2: 1, -3/2 + sqrt(5)/2: 1}

# %%
# !pip install gekko
# Out:
# ...
#      |████████████████████████████████| 10.6MB 4.3MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/c8/b5/0c/01d65f667ef39a1aff4038df02e1a52962f792916901ed7bc4
# Successfully built gekko
# ...

# %%
from gekko import GEKKO

m = GEKKO()

# variables
x1 = m.Var(value=0 , lb=0 , ub=5 , name='x1') # Product 1
x2 = m.Var(value=0 , lb=0 , ub=4 , name='x2') # Product 2
profit = m.Var(value=1 , name='profit')

# profit function
m.Obj(-profit)
m.Equation(profit==100*x1+125*x2)
m.Equation(3*x1+6*x2<=30)
m.Equation(8*x1+4*x2<=44)

m.solve()

print ('')
print ('--- Results of the Optimization Problem ---')
print ('Product 1 (x1): ' + str(x1[0]))
print ('Product 2 (x2): ' + str(x2[0]))
print ('Profit: ' + str(profit[0]))

## Generate a contour plot
# Import some other libraries that we'll need
# matplotlib and numpy packages must also be installed
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Design variables at mesh points
x = np.arange(-1.0, 8.0, 0.02)
y = np.arange(-1.0, 6.0, 0.02)
x1, x2 = np.meshgrid(x,y)

# Equations and Constraints
profit = 100.0 * x1 + 125.0 * x2
A_usage = 3.0 * x1 + 6.0 * x2
B_usage = 8.0 * x1 + 4.0 * x2

# Create a contour plot
plt.figure()
# Weight contours
lines = np.linspace(100.0,800.0,8)
CS = plt.contour(x1,x2,profit,lines,colors='g')
plt.clabel(CS, inline=1, fontsize=10)
# A usage < 30
CS = plt.contour(x1,x2,A_usage,[26.0, 28.0, 30.0],colors='r',linewidths=[0.5,1.0,4.0])
plt.clabel(CS, inline=1, fontsize=10)
# B usage < 44
CS = plt.contour(x1, x2,B_usage,[40.0,42.0,44.0],colors='b',linewidths=[0.5,1.0,4.0])
plt.clabel(CS, inline=1, fontsize=10)
# Container for 0 <= Product 1 <= 500 L
CS = plt.contour(x1, x2,x1 ,[0.0, 0.1, 4.9, 5.0],colors='k',linewidths=[4.0,1.0,1.0,4.0])
plt.clabel(CS, inline=1, fontsize=10)
# Container for 0 <= Product 2 <= 400 L
CS = plt.contour(x1, x2,x2 ,[0.0, 0.1, 3.9, 4.0],colors='k',linewidths=[4.0,1.0,1.0,4.0])
plt.clabel(CS, inline=1, fontsize=10)

# Add some labels
plt.title('Soft Drink Production Problem')
plt.xlabel('Product 1 (100 L)')
plt.ylabel('Product 2 (100 L)')
# Save the figure as a PNG
plt.savefig('contour.png')

# Show the plots
plt.show()
# Out:
# apm 34.83.2.252_gk_model0 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 0.9.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :            5
#    Intermediates:            0
#    Connections  :            0
#    Equations    :            4
#    Residuals    :            4
#
#  Number of state variables:              5
#  Number of total equations: -            3
#  Number of slack variables: -            2
#  ---------------------------------------
#  Degrees of freedom       :              0
#
#  **********************************************
#  Steady State Optimization with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ...

# %% [markdown]
# #[Numpy](https://numpy.org/)
#
# #[Scipy](https://www.scipy.org/)

# %%
import numpy as np
from scipy.optimize import minimize

def objective(x):
    return x[0]*x[3]*(x[0]+x[1]+x[2])+x[2]

def constraint1(x):
    return x[0]*x[1]*x[2]*x[3]-25.0

def constraint2(x):
    sum_eq = 40.0
    for i in range(4):
        sum_eq = sum_eq - x[i]**2
    return sum_eq

# initial guesses
n = 4
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0
x0[2] = 5.0
x0[3] = 1.0

# show initial objective
print('Initial SSE Objective: ' + str(objective(x0)))

# optimize
b = (1.0,5.0)
bnds = (b, b, b, b)
con1 = {'type': 'ineq', 'fun': constraint1} 
con2 = {'type': 'eq', 'fun': constraint2}
cons = ([con1,con2])
solution = minimize(objective,x0,method='SLSQP',\
                    bounds=bnds,constraints=cons)
x = solution.x

# show final objective
print('Final SSE Objective: ' + str(objective(x)))

# print solution
print('Solution')
print('x1 = ' + str(x[0]))
print('x2 = ' + str(x[1]))
print('x3 = ' + str(x[2]))
print('x4 = ' + str(x[3]))
# Out:
# Initial SSE Objective: 16.0
# Final SSE Objective: 17.01401724563517
# Solution
# x1 = 1.0
# x2 = 4.742996096883977
# x3 = 3.8211546234095715
# x4 = 1.379407645075325

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# animate plots?
animate=True # True / False

# define tank model
def tank(Level,time,c,valve):
    rho = 1000.0 # water density (kg/m^3)
    A = 1.0      # tank area (m^2)
    # calculate derivative of the Level
    dLevel_dt = (c/(rho*A)) * valve
    return dLevel_dt

# time span for the simulation for 10 sec, every 0.1 sec
ts = np.linspace(0,10,101)

# valve operation
c = 50.0          # valve coefficient (kg/s / %open)
u = np.zeros(101) # u = valve % open

# level initial condition
Level0 = 0

# initial valve position
valve = 10

# for storing the results
z = np.zeros(101)
es = np.zeros(101)
sps = np.zeros(101)

# TO DO: what is the value for ubias?
# ubias = ?

# TO DO: decide on a tuning value for Kc
# Kc = ?

# TO DO: record the desired level (set point)
SP = 1

plt.figure(1,figsize=(12,5))
if animate:
    plt.ion()
    plt.show()

# simulate with ODEINT
for i in range(100):
    # calculate the error
    error = SP - Level0

    # TO DO: put P-only controller here
    # valve = 1

    u[i+1] = valve   # store the valve position
    es[i+1] = error  # store the error 
    y = odeint(tank,Level0,[0,0.1],args=(c,valve))
    Level0 = y[-1] # take the last point
    z[i+1] = Level0 # store the level for plotting
    sps[i+1] = SP

    if animate:
        # update plot
        plt.clf()
        plt.subplot(3,1,1)
        plt.plot(ts[0:i+1],z[0:i+1],'r-',linewidth=3,label='level PV')
        plt.plot(ts[0:i+1],sps[0:i+1],'k:',linewidth=3,label='level SP')
        plt.ylabel('Tank Level')
        plt.legend(loc='best')
        plt.subplot(3,1,2)
        plt.plot(ts[0:i+1],u[0:i+1],'b--',linewidth=3,label='valve')
        plt.ylabel('Valve')    
        plt.legend(loc='best')
        plt.subplot(3,1,3)
        plt.plot(ts[0:i+1],es[0:i+1],'g-',linewidth=3,label='error')
        plt.ylabel('Error = SP-PV')
        plt.xlabel('Time (sec)')
        plt.legend(loc='best')
        plt.pause(0.1)

if not animate:
    # plot results
    plt.subplot(3,1,1)
    plt.plot(ts,z,'r-',linewidth=3,label='level PV')
    plt.plot(ts,sps,'k:',linewidth=3,label='level SP')
    plt.ylabel('Tank Level')
    plt.legend(loc='best')
    plt.subplot(3,1,2)
    plt.plot(ts,u,'b--',linewidth=3,label='valve')
    plt.ylabel('Valve')    
    plt.legend(loc='best')
    plt.subplot(3,1,3)
    plt.plot(ts,es,'g-',linewidth=3,label='error')
    plt.ylabel('Error = SP-PV')    
    plt.xlabel('Time (sec)')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# #[sympy in google](https://www.google.com/search?q=sumpy&rlz=1C1NDCM_enIN857IN857&oq=sumpy&aqs=chrome..69i57j0l5.2306j0j7&sourceid=chrome&ie=UTF-8)

# %%
from scipy.misc import derivative

# %%
def f(x):
  return (3*x**2+1)

# %%
a = f(x)

# %%
b = derivative(f,2)

# %%
print("the derivative of a = ",a)

# %%
print("is",b)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
y = np.linspace(-3,3)
plt.plot(y,f(y))

# %%
def d(x):
  return derivative(f,x)

# %%
print(d(2.0))

# %%
plt.plot(y,d(y))

# %%
y = np.linspace(-3,3)
plt.plot(y,f(y))
plt.plot(y,d(y))

# %%
import sympy as sp
from sympy.plotting import  plot 
x = sp.symbols("x")

# %%
#the list of the functional variables

# %%
f = 1
g = x
h = x**2
i = x**3
j = sp.sin(x)
k = sp.E**x

# %%
funclist = [f ,g ,h ,i ,j ,k]

# %%
for func in funclist:
  print("the derivative of\n"+sp.pretty(func)+"\nis \n"+
       sp.pretty(sp.diff(func,x))+"\n\n")

# %%
fprime = sp.diff(i,x)
m = fprime.subs(x,-.5)

# %%
print("the fprime value is:",fprime)

# %%
print(m)

# %%
yo = i.subs(x,-.5)

# %%
print("the value of y0",yo)

# %%
line = m*x +(-m*(-.5)+yo)

# %%
p  = plot(i,xlim = (-2,2),ylim = (-1,1),line_color = "r",legend = True,show = False)

# %%
p2  = plot(line,xlim = (-2,2),ylim = (-1,1),line_color = "b",legend = True,show = False)

# %%
p.show()
p2.show()
plt.show()

# %%
p = plot(k,xlim = (-5,5),ylim  = (-3,3),line_color = "b",legend = True,show = False)
p2 = plot(sp.diff(k,x),xlim = (-5,5),ylim = (-3,3),line_color = "r",legend = True,show = False)

# %%
p.show()
p2.show()
plt.show()

# %%
help(Abs)

# %%
print(sp.diff(2*x**112,x))

# %%
print(sp.diff(2,x))

# %%
sp.plot(2 + 10**(-10)*x ,xlim = (-4,4),ylim = (-1,3))

# %%
plot(x**(3) - 1 ,xlim = (-1,2),ylim = (-1,2),line_color = "b",show = True)
p2 = plot((3**(x-1)) ,xlim = (-1,2),ylim = (-1,2),line_color = "r",show = True)
p.append(p2[0])
p.show()

# %%
p2 = plot((3*(x-1)) ,xlim = (-1,2),ylim = (-1,2),line_color = "r",show = True)
p.append(p2[0])
p.show()

# %%
sp.plot(x**2-5*x+6,xlim = (-1,4),ylim = (-2,3))

# %%
p3 = plot((x**2-5*x+6),xlim=(-1,4),ylim = (-2,3),line_color = "r",show = True)

# %% [markdown]
# #The Power Rule

# %%
[x^0]

# %%
[x]

# %%
#the Derivvative of ARC Cosine
sp.asin(x)

# %%
a = sp.diff(sp.asin(x))

# %%
print(sp.pprint(a))
# Out:
# 10
# None
